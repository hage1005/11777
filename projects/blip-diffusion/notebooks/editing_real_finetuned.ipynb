# %%
# !pip install 'git+https://github.com/salesforce/LAVIS.git'
# Out:
# Collecting git+https://github.com/salesforce/LAVIS.git
#   Cloning https://github.com/salesforce/LAVIS.git to /tmp/pip-req-build-0t4kirhk
#   Running command git clone --filter=blob:none --quiet https://github.com/salesforce/LAVIS.git /tmp/pip-req-build-0t4kirhk
#   Resolved https://github.com/salesforce/LAVIS.git to commit 7f00a0891b2890843f61c002a8e9532a40343648
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting contexttimer (from salesforce-lavis==1.0.1)
#   Downloading contexttimer-0.3.3.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting decord (from salesforce-lavis==1.0.1)
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 96.4 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Collecting diffusers<=0.16.0 (from salesforce-lavis==1.0.1)
#   Downloading diffusers-0.16.0-py3-none-any.whl (934 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.8/934.8 kB 78.3 MB/s eta 0:00:00
# Collecting einops>=0.4.1 (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for einops>=0.4.1 from https://files.pythonhosted.org/packages/29/0b/2d1c0ebfd092e25935b86509a9a817159212d82aa43d7fb07eca4eeff2c2/einops-0.7.0-py3-none-any.whl.metadata
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting fairscale==0.4.4 (from salesforce-lavis==1.0.1)
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ftfy (from salesforce-lavis==1.0.1)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 18.5 MB/s eta 0:00:00
# Collecting iopath (from salesforce-lavis==1.0.1)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (8.16.1)
# Collecting omegaconf (from salesforce-lavis==1.0.1)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 26.0 MB/s eta 0:00:00
# Collecting opencv-python-headless==4.5.5.64 (from salesforce-lavis==1.0.1)
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 MB 40.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting opendatasets (from salesforce-lavis==1.0.1)
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: packaging in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (21.3)
# Requirement already satisfied: pandas in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (2.1.1)
# Collecting plotly (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/a8/07/72953cf70e3bd3a24cbc3e743e6f8539abe6e3e6d83c3c0c83426eaffd39/plotly-5.18.0-py3-none-any.whl.metadata
#   Downloading plotly-5.18.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting pre-commit (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for pre-commit from https://files.pythonhosted.org/packages/6c/75/526915fedf462e05eeb1c75ceaf7e3f9cde7b5ce6f62740fe5f7f19a0050/pre_commit-3.5.0-py2.py3-none-any.whl.metadata
#   Downloading pre_commit-3.5.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting pycocoevalcap (from salesforce-lavis==1.0.1)
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 19.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting pycocotools (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/ba/64/0451cf41a00fd5ac4501de4ea0e395b7d909e09d665e56890b5d3809ae26/pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting python-magic (from salesforce-lavis==1.0.1)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting scikit-image (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for scikit-image from https://files.pythonhosted.org/packages/f1/6c/49f5a0ce8ddcdbdac5ac69c129654938cc6de0a936303caa6cad495ceb2a/scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting sentencepiece (from salesforce-lavis==1.0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.3 MB/s eta 0:00:00 eta 0:00:01
# Collecting spacy (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/d6/c8/d659de66da2be05ad10fe029954a90a5fb6ddffb75aaab6702173e9dd0c9/spacy-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading spacy-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting streamlit (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/34/01/9d1460a6e71d6226e1f5c5053de20758c41100c5c15abb73551273a96fb8/streamlit-1.27.2-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.27.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting timm==0.4.12 (from salesforce-lavis==1.0.1)
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 62.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (2.0.1)
# Requirement already satisfied: torchvision in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (0.15.2)
# Requirement already satisfied: tqdm in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (4.66.1)
# Collecting transformers>=4.28.0 (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for transformers>=4.28.0 from https://files.pythonhosted.org/packages/c1/bd/f64d67df4d3b05a460f281defe830ffab6d7940b7ca98ec085e94e024781/transformers-4.34.1-py3-none-any.whl.metadata
#   Downloading transformers-4.34.1-py3-none-any.whl.metadata (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 35.6 MB/s eta 0:00:00
# Collecting webdataset (from salesforce-lavis==1.0.1)
#   Obtaining dependency information for webdataset from https://files.pythonhosted.org/packages/c4/7c/7ea7c0bcea85fd4eeceade6cc3fe596300b1a00cc53f2192b6eda603573b/webdataset-0.2.65-py3-none-any.whl.metadata
#   Downloading webdataset-0.2.65-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: wheel in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from salesforce-lavis==1.0.1) (0.41.2)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opencv-python-headless==4.5.5.64->salesforce-lavis==1.0.1) (1.25.2)
# Requirement already satisfied: Pillow in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from diffusers<=0.16.0->salesforce-lavis==1.0.1) (10.0.1)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from diffusers<=0.16.0->salesforce-lavis==1.0.1) (3.12.4)
# Collecting huggingface-hub>=0.13.2 (from diffusers<=0.16.0->salesforce-lavis==1.0.1)
#   Obtaining dependency information for huggingface-hub>=0.13.2 from https://files.pythonhosted.org/packages/ef/b5/b6107bd65fa4c96fdf00e4733e2fe5729bb9e5e09997f63074bb43d3ab28/huggingface_hub-0.18.0-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from diffusers<=0.16.0->salesforce-lavis==1.0.1) (6.8.0)
# Collecting regex!=2019.12.17 (from diffusers<=0.16.0->salesforce-lavis==1.0.1)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/8f/3e/4b8b40eb3c80aeaf360f0361d956d129bb3d23b2a3ecbe3a04a8f3bdd6d3/regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from diffusers<=0.16.0->salesforce-lavis==1.0.1) (2.31.0)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.10.0->salesforce-lavis==1.0.1) (4.8.0)
# Requirement already satisfied: sympy in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.10.0->salesforce-lavis==1.0.1) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.10.0->salesforce-lavis==1.0.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.10.0->salesforce-lavis==1.0.1) (3.1.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from transformers>=4.28.0->salesforce-lavis==1.0.1) (6.0.1)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.28.0->salesforce-lavis==1.0.1)
#   Obtaining dependency information for tokenizers<0.15,>=0.14 from https://files.pythonhosted.org/packages/a7/7b/c1f643eb086b6c5c33eef0c3752e37624bd23e4cbc9f1332748f1c6252d1/tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers>=4.28.0->salesforce-lavis==1.0.1)
#   Obtaining dependency information for safetensors>=0.3.1 from https://files.pythonhosted.org/packages/20/4e/878b080dbda92666233ec6f316a53969edcb58eab1aa399a64d0521cf953/safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from packaging->salesforce-lavis==1.0.1) (3.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ftfy->salesforce-lavis==1.0.1) (0.2.8)
# Collecting portalocker (from iopath->salesforce-lavis==1.0.1)
#   Obtaining dependency information for portalocker from https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl.metadata
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: backcall in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from ipython->salesforce-lavis==1.0.1) (4.8.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->salesforce-lavis==1.0.1)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 36.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting kaggle (from opendatasets->salesforce-lavis==1.0.1)
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 21.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from opendatasets->salesforce-lavis==1.0.1) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->salesforce-lavis==1.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->salesforce-lavis==1.0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->salesforce-lavis==1.0.1) (2023.3)
# Collecting tenacity>=6.2.0 (from plotly->salesforce-lavis==1.0.1)
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting cfgv>=2.0.0 (from pre-commit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for cfgv>=2.0.0 from https://files.pythonhosted.org/packages/c5/55/51844dd50c4fc7a33b653bfaba4c2456f06955289ca770a5dbd5fd267374/cfgv-3.4.0-py2.py3-none-any.whl.metadata
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for identify>=1.0.0 from https://files.pythonhosted.org/packages/34/67/efd868b790f08deb931574df58381df79f59c0ec4eb5fd67ed00328a414f/identify-2.5.30-py2.py3-none-any.whl.metadata
#   Downloading identify-2.5.30-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for nodeenv>=0.11.1 from https://files.pythonhosted.org/packages/1a/e6/6d2ead760a9ddb35e65740fd5a57e46aadd7b0c49861ab24f94812797a1c/nodeenv-1.8.0-py2.py3-none-any.whl.metadata
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for virtualenv>=20.10.0 from https://files.pythonhosted.org/packages/7f/19/1f0eddcb9acf00a95793ce83417f69e0fd106c192121360af499cd6fde39/virtualenv-20.24.6-py3-none-any.whl.metadata
#   Downloading virtualenv-20.24.6-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pycocotools->salesforce-lavis==1.0.1) (3.8.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from scikit-image->salesforce-lavis==1.0.1) (1.11.3)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from scikit-image->salesforce-lavis==1.0.1) (2.31.1)
# Collecting tifffile>=2022.8.12 (from scikit-image->salesforce-lavis==1.0.1)
#   Obtaining dependency information for tifffile>=2022.8.12 from https://files.pythonhosted.org/packages/f5/72/68ea763b5f3e3d9871492683059ed4724fd700dbe54aa03cdda7a9692129/tifffile-2023.9.26-py3-none-any.whl.metadata
#   Downloading tifffile-2023.9.26-py3-none-any.whl.metadata (30 kB)
# Collecting lazy_loader>=0.3 (from scikit-image->salesforce-lavis==1.0.1)
#   Obtaining dependency information for lazy_loader>=0.3 from https://files.pythonhosted.org/packages/a1/c3/65b3814e155836acacf720e5be3b5757130346670ac454fee29d3eda1381/lazy_loader-0.3-py3-none-any.whl.metadata
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy->salesforce-lavis==1.0.1)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/a8/ca/359ae4246cccaf3f6386b66bd9ba4a39e6ec342f89e2c4def361a8cbe7cf/murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for cymem<2.1.0,>=2.0.2 from https://files.pythonhosted.org/packages/e9/13/3bed1a1d1cce7937eb797d760c0cca973dbdc1891ad7e2f066ae418fd697/cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for preshed<3.1.0,>=3.0.2 from https://files.pythonhosted.org/packages/42/59/8f65ad22c13020ff281529e415c32a56cfa691d24b0eca2eb3d756e4d644/preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for thinc<8.3.0,>=8.1.8 from https://files.pythonhosted.org/packages/a9/75/fefdbcb0f32ccc4c67042d3554734b8c5203d9fa7e30112f57af5a7e33d8/thinc-8.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading thinc-8.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for wasabi<1.2.0,>=0.9.1 from https://files.pythonhosted.org/packages/8f/69/26cbf0bad11703241cb84d5324d868097f7a8faf2f1888354dac8883f3fc/wasabi-1.1.2-py3-none-any.whl.metadata
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for srsly<3.0.0,>=2.4.3 from https://files.pythonhosted.org/packages/32/69/2c054c6c5dc5daf5648f994f22377f3be44f79d643f3c3db255b4e86b391/srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for catalogue<2.1.0,>=2.0.6 from https://files.pythonhosted.org/packages/9e/96/d32b941a501ab566a16358d68b6eb4e4acc373fab3c3c4d7d9e649f7b4bb/catalogue-2.0.10-py3-none-any.whl.metadata
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for weasel<0.4.0,>=0.1.0 from https://files.pythonhosted.org/packages/a6/76/41433e70b7c9ed47db8206536ecc6408362db44111c27f59e76af20377f2/weasel-0.3.3-py3-none-any.whl.metadata
#   Downloading weasel-0.3.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy->salesforce-lavis==1.0.1)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 13.4 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for smart-open<7.0.0,>=5.2.1 from https://files.pythonhosted.org/packages/fc/d9/d97f1db64b09278aba64e8c81b5d322d436132df5741c518f3823824fae0/smart_open-6.4.0-py3-none-any.whl.metadata
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from spacy->salesforce-lavis==1.0.1) (2.4.2)
# Requirement already satisfied: setuptools in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from spacy->salesforce-lavis==1.0.1) (68.2.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy->salesforce-lavis==1.0.1)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 43.2 MB/s eta 0:00:00
# Collecting altair<6,>=4.0 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/17/16/b12fca347ff9d062e3c44ad9641d2ec50364570a059f3078ada3a5119d7a/altair-5.1.2-py3-none-any.whl.metadata
#   Downloading altair-5.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from streamlit->salesforce-lavis==1.0.1) (1.6.2)
# Collecting cachetools<6,>=4.0 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from streamlit->salesforce-lavis==1.0.1) (4.24.3)
# Requirement already satisfied: pyarrow>=6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from streamlit->salesforce-lavis==1.0.1) (13.0.0)
# Collecting rich<14,>=10.14.0 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/be/2a/4e62ff633612f746f88618852a626bbe24226eba5e7ac90e91dcfd6a414e/rich-13.6.0-py3-none-any.whl.metadata
#   Downloading rich-13.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->salesforce-lavis==1.0.1)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tzlocal<6,>=1.1 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for tzlocal<6,>=1.1 from https://files.pythonhosted.org/packages/97/3f/c4c51c55ff8487f2e6d0e618dba917e3c3ee2caae6cf0fbb59c9b1876f2e/tzlocal-5.2-py3-none-any.whl.metadata
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/3a/0c/785d317eea99c3739821718f118c70537639aa43f96bfa1d83a71f68eaf6/validators-0.22.0-py3-none-any.whl.metadata
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->salesforce-lavis==1.0.1)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 21.8 MB/s eta 0:00:000m eta 0:00:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from streamlit->salesforce-lavis==1.0.1) (6.3.3)
# Collecting watchdog>=2.1.5 (from streamlit->salesforce-lavis==1.0.1)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 27.2 MB/s eta 0:00:00
# Collecting braceexpand (from webdataset->salesforce-lavis==1.0.1)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1) (4.19.1)
# Collecting toolz (from altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 17.3 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub>=0.13.2->diffusers<=0.16.0->salesforce-lavis==1.0.1) (2023.9.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from importlib-metadata->diffusers<=0.16.0->salesforce-lavis==1.0.1) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jedi>=0.16->ipython->salesforce-lavis==1.0.1) (0.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools->salesforce-lavis==1.0.1) (1.4.5)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pexpect>4.3->ipython->salesforce-lavis==1.0.1) (0.7.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->salesforce-lavis==1.0.1) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->salesforce-lavis==1.0.1) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->salesforce-lavis==1.0.1) (2.1.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->salesforce-lavis==1.0.1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->diffusers<=0.16.0->salesforce-lavis==1.0.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->diffusers<=0.16.0->salesforce-lavis==1.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->diffusers<=0.16.0->salesforce-lavis==1.0.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->diffusers<=0.16.0->salesforce-lavis==1.0.1) (2023.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for blis<0.8.0,>=0.7.8 from https://files.pythonhosted.org/packages/9b/81/55092e1c016fe05ef7a57623920209012f05e8b897acbad355c9bf854181/blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for confection<1.0.0,>=0.0.1 from https://files.pythonhosted.org/packages/93/f8/e89268a1f885048fb2ee6b5c9f93c4e90de768534acfef3652f87d97d4cb/confection-0.1.3-py3-none-any.whl.metadata
#   Downloading confection-0.1.3-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface-hub>=0.13.2 (from diffusers<=0.16.0->salesforce-lavis==1.0.1)
#   Obtaining dependency information for huggingface-hub>=0.13.2 from https://files.pythonhosted.org/packages/aa/f3/3fc97336a0e90516901befd4f500f08d691034d387406fdbde85bea827cc/huggingface_hub-0.17.3-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for distlib<1,>=0.3.7 from https://files.pythonhosted.org/packages/43/a0/9ba967fdbd55293bacfc1507f58e316f740a3b231fc00e3d86dc39bc185a/distlib-0.3.7-py2.py3-none-any.whl.metadata
#   Downloading distlib-0.3.7-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit->salesforce-lavis==1.0.1) (3.11.0)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy->salesforce-lavis==1.0.1)
#   Obtaining dependency information for cloudpathlib<0.17.0,>=0.7.0 from https://files.pythonhosted.org/packages/0f/6e/45b57a7d4573d85d0b0a39d99673dc1f5eea9d92a1a4603b35e968fbf89a/cloudpathlib-0.16.0-py3-none-any.whl.metadata
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Collecting python-slugify (from kaggle->opendatasets->salesforce-lavis==1.0.1)
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: bleach in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from kaggle->opendatasets->salesforce-lavis==1.0.1) (6.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from stack-data->ipython->salesforce-lavis==1.0.1) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from stack-data->ipython->salesforce-lavis==1.0.1) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from stack-data->ipython->salesforce-lavis==1.0.1) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from sympy->torch>=1.10.0->salesforce-lavis==1.0.1) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->salesforce-lavis==1.0.1)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->salesforce-lavis==1.0.1) (0.10.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->salesforce-lavis==1.0.1)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: webencodings in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from bleach->kaggle->opendatasets->salesforce-lavis==1.0.1) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle->opendatasets->salesforce-lavis==1.0.1)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 21.1 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 11.9 MB/s eta 0:00:00
# Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 114.1 MB/s eta 0:00:001m220.4 MB/s eta 0:00:01
# Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 86.7 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading pre_commit-3.5.0-py2.py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 54.1 MB/s eta 0:00:00
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 71.7 MB/s eta 0:00:00
# Downloading scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 57.7 MB/s eta 0:00:000m eta 0:00:0136m0:00:01
# Downloading spacy-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 25.7 MB/s eta 0:00:000m eta 0:00:010:01
# Downloading streamlit-1.27.2-py2.py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 25.4 MB/s eta 0:00:000m eta 0:00:01
# Downloading webdataset-0.2.65-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 694.7 kB/s eta 0:00:000:00:01
# Downloading altair-5.1.2-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.2/516.2 kB 4.2 MB/s eta 0:00:000m eta 0:00:01
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 14.6 MB/s eta 0:00:00
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 51.7 MB/s eta 0:00:00
# Downloading identify-2.5.30-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 31.1 MB/s eta 0:00:00
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 kB 39.7 MB/s eta 0:00:00
# Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 6.5 MB/s eta 0:00:000m eta 0:00:01
# Downloading rich-13.6.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.8/239.8 kB 57.4 MB/s eta 0:00:00
# Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.8 MB/s eta 0:00:00 eta 0:00:01
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 349.9 kB/s eta 0:00:001m236.4 MB/s eta 0:00:01
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.0/493.0 kB 76.5 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading thinc-8.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.6/920.6 kB 98.1 MB/s eta 0:00:00
# Downloading tifffile-2023.9.26-py3-none-any.whl (222 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 kB 55.4 MB/s eta 0:00:00
# Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 114.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 52.7 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading virtualenv-20.24.6-py3-none-any.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 21.9 MB/s eta 0:00:000m eta 0:00:01
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 14.2 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Downloading blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 17.5 MB/s eta 0:00:000m eta 0:00:01:01
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 14.7 MB/s eta 0:00:00
# Downloading confection-0.1.3-py3-none-any.whl (34 kB)
# Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 73.5 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 20.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 27.8 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: salesforce-lavis, fairscale, contexttimer, iopath, antlr4-python3-runtime, kaggle
#   Building wheel for salesforce-lavis (pyproject.toml) ... done
#   Created wheel for salesforce-lavis: filename=salesforce_lavis-1.0.1-py3-none-any.whl size=2435475 sha256=ab7864d92a2af6106758c1dc3ed1c8edd0863a632e5b44a938ac96a0f23b54c8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q_cvjrhn/wheels/7f/44/c5/9a456d59450e09fcee8f2fe6947c594b39437634487db96ebd
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292830 sha256=86ef524492575e9cbfe0a06784a5bf2373557f9d41c96f04efeb9f6ce1f65b98
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/08/58/6f/56c57fa8315eb0bcf0287b580c850845be5f116359b809e9f1
#   Building wheel for contexttimer (setup.py) ... done
#   Created wheel for contexttimer: filename=contexttimer-0.3.3-py3-none-any.whl size=5804 sha256=2e4782a8df83e82c2e5d7fe75a491bfebb17827a4f93c42aea44b92c99eb0ce8
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/72/1c/da/cfd97201d88ccce214427fa84a5caeb91fef7c5a1b4c4312b4
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31530 sha256=8545b9ab2f35af3eb962f85cf19a2655a256f614e0848b9ee335d77879b093b8
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c83fab30fc8db9b1fa0d2dc2cf06d4391df1a6af76de6cc6ed04e4b782de4dac
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110683 sha256=42c2465a04f5c61ed0218e84f5eeac1123aaf9aa79eb2a99169352074d94bcd9
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/43/4b/fb/736478af5e8004810081a06259f9aa2f7c3329fc5d03c2c412
# Successfully built salesforce-lavis fairscale contexttimer iopath antlr4-python3-runtime kaggle
# Installing collected packages: text-unidecode, sentencepiece, distlib, cymem, contexttimer, braceexpand, antlr4-python3-runtime, webdataset, watchdog, wasabi, virtualenv, validators, tzlocal, typer, toolz, toml, tifffile, tenacity, spacy-loggers, spacy-legacy, smmap, smart-open, safetensors, regex, python-slugify, python-magic, portalocker, opencv-python-headless, omegaconf, nodeenv, murmurhash, mdurl, lazy_loader, langcodes, identify, ftfy, einops, decord, cloudpathlib, cfgv, catalogue, cachetools, blis, srsly, scikit-image, pydeck, preshed, pre-commit, plotly, markdown-it-py, kaggle, iopath, huggingface-hub, gitdb, tokenizers, rich, pycocotools, opendatasets, gitpython, fairscale, diffusers, confection, weasel, transformers, timm, thinc, pycocoevalcap, altair, streamlit, spacy, salesforce-lavis
# Successfully installed altair-5.1.2 antlr4-python3-runtime-4.9.3 blis-0.7.11 braceexpand-0.1.7 cachetools-5.3.2 catalogue-2.0.10 cfgv-3.4.0 cloudpathlib-0.16.0 confection-0.1.3 contexttimer-0.3.3 cymem-2.0.8 decord-0.6.0 diffusers-0.16.0 distlib-0.3.7 einops-0.7.0 fairscale-0.4.4 ftfy-6.1.1 gitdb-4.0.11 gitpython-3.1.40 huggingface-hub-0.17.3 identify-2.5.30 iopath-0.1.10 kaggle-1.5.16 langcodes-3.3.0 lazy_loader-0.3 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 nodeenv-1.8.0 omegaconf-2.3.0 opencv-python-headless-4.5.5.64 opendatasets-0.1.22 plotly-5.18.0 portalocker-2.8.2 pre-commit-3.5.0 preshed-3.0.9 pycocoevalcap-1.2 pycocotools-2.0.7 pydeck-0.8.1b0 python-magic-0.4.27 python-slugify-8.0.1 regex-2023.10.3 rich-13.6.0 safetensors-0.4.0 salesforce-lavis-1.0.1 scikit-image-0.22.0 sentencepiece-0.1.99 smart-open-6.4.0 smmap-5.0.1 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 streamlit-1.27.2 tenacity-8.2.3 text-unidecode-1.3 thinc-8.2.1 tifffile-2023.9.26 timm-0.4.12 tokenizers-0.14.1 toml-0.10.2 toolz-0.12.0 transformers-4.34.1 typer-0.9.0 tzlocal-5.2 validators-0.22.0 virtualenv-20.24.6 wasabi-1.1.2 watchdog-3.0.0 weasel-0.3.3 webdataset-0.2.65

# %%
import torch
import requests

from PIL import Image
from lavis.models import load_model_and_preprocess

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model, vis_preprocess, txt_preprocess = load_model_and_preprocess("blip_diffusion", "base", device="cuda", is_eval=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 555M/555M [00:16<00:00, 35.8MB/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading (…)_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Downloading (…)main/vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Downloading (…)ain/unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# Downloading (…)ch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# /opt/conda/envs/pytorch/lib/python3.10/site-packages/diffusers/configuration_utils.py:215: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 6.95G/6.95G [04:37<00:00, 26.9MB/s]
# No ctx_embeddings_cache found in /home/ec2-user/.cache/torch/hub/checkpoints/blip-diffusion

# %% [markdown]
# ### Description
# This demo shows how to edit a **real** image with a finetuned checkpoint on a given subject. It works in the following steps:
#
# (1) load the finetuned checkpoint.
#
# (2) run DDIM inversion on the given image using prompt ``A ${src_subject} ${prompt}.``;
#
# (3) extracting BLIP-2 embeddings on condition subject image, using ``cond_subject`` and ``cond_image``.
#
# (4) edit the real image with the subject visuals, using the prompt ``A ${BLIP-2 embedding} ${tgt_subject} ${prompt}`` and the DDIM inverted latents.

# %%
finetuned_ckpt = "https://storage.googleapis.com/sfr-vision-language-research/LAVIS/models/BLIP-Diffusion/db-dog/checkpoint_40.pth"
# can also use a local checkpoint
# finetuned_ckpt = "../checkpoints/db-dog/checkpoint_40.pth"
model.load_checkpoint(finetuned_ckpt)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 9.69G/9.69G [03:03<00:00, 56.8MB/s]
# loading fine-tuned model from https://storage.googleapis.com/sfr-vision-language-research/LAVIS/models/BLIP-Diffusion/db-dog/checkpoint_40.pth

# %%
cond_subject = "cat"
src_subject = "dog"
tgt_subject = "cat"

text_prompt = "sit on grass"

cond_subject = txt_preprocess["eval"](cond_subject)
src_subject = txt_preprocess["eval"](src_subject)
tgt_subject = txt_preprocess["eval"](tgt_subject)
text_prompt = [txt_preprocess["eval"](text_prompt)]

src_image = Image.open("../images/dog2.png").convert("RGB")
display(src_image.resize((256, 256)))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
url = "https://arbordayblog.org/wp-content/uploads/2019/08/iStock-961007580-1-1080x608.jpg"
img = requests.get(url, stream=True).raw
src_image = Image.open(img).convert("RGB")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[21], line 3
#       1 url = "https://arbordayblog.org/wp-content/uploads/2019/08/iStock-961007580-1-1080x608.jpg"
#       2 img = requests.get(url, stream=True).raw
# ----> 3 src_image = Image.open(img)
#
# File /opt/conda/envs/pytorch/lib/python3.10/site-packages/PIL/Image.py:3280, in open(fp, mode, formats)
#    3278     warnings.warn(message)
#    3279 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3280 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7eff59159df0>

# %%
samples = {
    "cond_images": None,
    "cond_subject": cond_subject,
    "src_subject": src_subject,
    "tgt_subject": tgt_subject,
    "prompt": text_prompt,
    "raw_image": src_image,
}

# %%
iter_seed = 8887
guidance_scale = 7.5
num_inference_steps = 50 
num_inversion_steps = 50 # increase to improve DDIM inversion quality
lb_threshold = 0.3 # increase to edit fewer pixels.
negative_prompt = "over-exposure, under-exposure, saturated, duplicate, out of frame, lowres, cropped, worst quality, low quality, jpeg artifacts, morbid, mutilated, out of frame, ugly, bad anatomy, bad proportions, deformed, blurry, duplicate"

output = model.edit(
    samples,
    seed=iter_seed,
    guidance_scale=guidance_scale,
    num_inference_steps=num_inference_steps,
    num_inversion_steps=num_inversion_steps,
    neg_prompt=negative_prompt,
    lb_threshold=lb_threshold,
)

print("=" * 30)
print("Before editing:")
display(output[0])

print("After editing:")
display(output[1])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:12<00:00,  3.92it/s]
# ['a dog sit on grass', 'a sks sks sks sks sks sks sks sks sks sks sks sks sks sks sks sks cat sit on grass']
# 100%|█████████████████████████████████████████████████████████████████████████████████| 50/50 [00:47<00:00,  1.05it/s]
# ==============================
# Before editing:
# <PIL.Image.Image image mode=RGB size=512x512>
# After editing:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
output[0].size
# Out:
# (512, 512)
